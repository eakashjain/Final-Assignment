# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Akash Kumar Jain__
# Data Scientist

# %% [markdown]
# *I am interested in data science because it will make my career future proof. Data is the new gold and I want to be a goldsmith.*

# %% [markdown]
# ### My code will find the remainder when 35 is divided by 3

# %%
35%3
# Out:
# 2

# %% [markdown]
# Horizontal rule
#
# ---
#
# * Bulllet list
# * as above
#
#
# 1. Numbered list
# 2. as above
#
# | This        | is   a        | Table  |
# | ------------- |:-------------:| -----:|
# | Are      | we | Sure |
#
#
# > This is a block quote
